# %%
from scipy import stats
import numpy as np

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
z = (214-200)/(10/np.sqrt(4))
z
# Out:
# 2.8

# %%
p_value = 1 - stats.norm(0,1).cdf(z)
p_value
# Out:
# 0.0025551303304279793
